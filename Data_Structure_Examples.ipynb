# %% [markdown]
# <a href="https://colab.research.google.com/github/raghunatht-twi/Regression_py/blob/main/Data_Structure_Examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3a4253c8-870c-4558-8a32-dbb505909467" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a4253c8-870c-4558-8a32-dbb505909467">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("country_timeseries.csv")

# %%
df.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
df_formatted = pd.melt(df, id_vars=['Date', 'Day'], var_name='Region', value_name='Case_Count')

# %%
df_formatted.head()
# Out:
#          Date  Day        Region  Case_Count
# 0    1/5/2015  289  Cases_Guinea      2776.0
# 1    1/4/2015  288  Cases_Guinea      2775.0
# 2    1/3/2015  287  Cases_Guinea      2769.0
# 3    1/2/2015  286  Cases_Guinea         NaN
# 4  12/31/2014  284  Cases_Guinea      2730.0

# %%
df_formatted[['Stats', 'Country']]= (df_formatted['Region'].str.split('_', expand=True))

# %%
df_formatted = df_formatted[['Date', 'Day', 'Country', 'Case_Count', 'Stats']]

# %%
df_formatted.head()
# Out:
#          Date  Day Country  Case_Count  Stats
# 0    1/5/2015  289  Guinea      2776.0  Cases
# 1    1/4/2015  288  Guinea      2775.0  Cases
# 2    1/3/2015  287  Guinea      2769.0  Cases
# 3    1/2/2015  286  Guinea         NaN  Cases
# 4  12/31/2014  284  Guinea      2730.0  Cases
